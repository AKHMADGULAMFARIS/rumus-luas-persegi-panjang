# %% [markdown]
# <a href="https://colab.research.google.com/github/AKHMADGULAMFARIS/rumus-luas-persegi-panjang/blob/main/Kelompok_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# kelompok 5

# %%
panjang=50
lebar=20
luas=panjang*lebar
print('luas persegi panjang adalah',luas,'cm')
# Out:
# luas persegi panjang adalah 1000 cm
